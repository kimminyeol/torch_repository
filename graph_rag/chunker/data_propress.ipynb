# %%
import pandas as pd 

df= pd.read_csv('chunked_output.csv')

# %%
df.iloc[:10].to_csv('co.csv',index=False)

# %%
df
# Out:
#      chunk_id  start_token  end_token  \
# 0           0            0        600
# 1           1          500       1100
# 2           2         1000       1600
# 3           3         1500       2100
# 4           4         2000       2600
# ..        ...          ...        ...
# 160       160        80000      80600
# 161       161        80500      81100
# 162       162        81000      81600
# 163       163        81500      82100
# 164       164        82000      82204
#
#                                                   text
# 0    FORM 10-K FORM 10-KUNITED STATES\nSECURITIES A...
# 1    •whether the registrant is a large accelerated...
# 2    , are incorporated by reference into Part III ...
# 3    \nGENERAL\nNIKE, Inc. was incorporated in 1967...
# 4    letic use, although many of the products are w...
# ..                                                 ...
# 160  The Exhibits filed herewith do not include cer...
# 161   over financial \nreporting, which appears in ...
# ...
